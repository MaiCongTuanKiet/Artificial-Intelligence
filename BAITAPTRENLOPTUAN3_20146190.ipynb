# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiCongTuanKiet/Artificial-Intelligence/blob/main/BAITAPTRENLOPTUAN3_20146190.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import write
with open ('text.txt', mode='w') as accounts:
  accounts.write('20146190 Mai Cong Tuan Kiet 10\n')

# %%
with open ('text1.txt', mode='w') as accounts:
  print('20146190 Mai Cong Tuan Kiet', file=accounts)

# %%
with open ('text1.txt', mode='r') as accounts:
  print(f'{'MSSV':<10}{'Name':<20}{'Score':>2}')
  for record in accounts:
    mssv, name, score=record.split()
    print(f'{'mssv':<10}{'name':<20}{'score':>2})
# Out:
#   File "<ipython-input-11-750b8dc72a5b>", line 2
#     print(f'{'MSSV':<10}{'Name':<20}{'Score':>2}')
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
url='AITUAN.csv'
dataframe=pd.read_csv(url)
dataframe.head(21)
# Out:
#     No      MSSV           Họ và tên Khoa  Điểm
# 0    1  20146589   Mai Thị Tuấn Kiệt  CKM    10
# 1    2  19586355  Bùi Thị Thanh Kiệt  CKM    10
# 2    3  15896589      Trần Ngọc Phấn  CKM    10
# 3    4  18965632    Lý Thị Khải Hoàn  CKM    10
# 4    5  17856985  Bùi Thị Thanh Ngân  CKM    10
# 5    6  19654896     Trần Thanh Phát  CKM    10
# 6    7  21456985          Lý Mạc Sầu  CKM    10
# 7    8  19566589      Nguyễn Anh Thư  CKM    10
# 8    9  20146179        Lê Thanh Tâm  CKM    10
# 9   10  20146182        Lý Minh Nhựt  CKM    10
# 10  11  20146185         Trần Văn Hô  CKM    10
# 11  12  20146188      Nguyễn Thị Anh  CKM    10
# 12  13  20146191        Lê Minhh Hòa  CKM    10
# 13  14  20146194       Trần Khai Tâm  CKM    10
# 14  15  20146197       Nguyễn Văn Lé  CKM    10
# 15  16  20146200       Ninh Văn Minh  CKM    10
# 16  17  20146203       Trần Cao Bằng  CKM    10
# 17  18  20146206          Vũ Anh Thư  CKM    10
# 18  19  20146209      Trần Ánh Tuyết  CKM    10
# ...

# %%
import pandas as pd
url='AITUAN.csv'
print(' Điểm cao nhất',dataframe['Điểm'].max())
# Out:
#  Điểm cao nhất 10

# %%
import pandas as pd
url='AITUAN.csv'
print(' Điểm thấp nhất',dataframe['Điểm'].min())
# Out:
#  Điểm thấp nhất 10

# %%
import pandas as pd
url='AITUAN.csv'
dataframe['Khoa'].unique()
dataframe['Khoa'].value_counts()
# Out:
# CKM    20
# Name: Khoa, dtype: int64

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.drop('MSSV',axis=1).head(10)
# Out:
#    No           Họ và tên Khoa  Điểm
# 0   1   Mai Thị Tuấn Kiệt  CKM    10
# 1   2  Bùi Thị Thanh Kiệt  CKM    10
# 2   3      Trần Ngọc Phấn  CKM    10
# 3   4    Lý Thị Khải Hoàn  CKM    10
# 4   5  Bùi Thị Thanh Ngân  CKM    10
# 5   6     Trần Thanh Phát  CKM    10
# 6   7          Lý Mạc Sầu  CKM    10
# 7   8      Nguyễn Anh Thư  CKM    10
# 8   9        Lê Thanh Tâm  CKM    10
# 9  10        Lý Minh Nhựt  CKM    10

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.drop(dataframe, columns[2:4],axis=1).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-15bf174cb2e7> in <module>
#       1 import pandas as pd
#       2 url='AITUAN.csv'
# ----> 3 dataframe.drop(dataframe, columns[2:4],axis=1).head(10)
#
# NameError: name 'columns' is not defined

# %%
import pandas as pd
url='AITUAN.csv'
dataframe[dataframe['Khoa']!='CKM'].head(10)
# Out:
# Empty DataFrame
# Columns: [No, MSSV, Họ và tên, Khoa, Điểm]
# Index: []

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.drop_duplicates().head(10)
# Out:
#    No      MSSV           Họ và tên Khoa  Điểm
# 0   1  20146589   Mai Thị Tuấn Kiệt  CKM    10
# 1   2  19586355  Bùi Thị Thanh Kiệt  CKM    10
# 2   3  15896589      Trần Ngọc Phấn  CKM    10
# 3   4  18965632    Lý Thị Khải Hoàn  CKM    10
# 4   5  17856985  Bùi Thị Thanh Ngân  CKM    10
# 5   6  19654896     Trần Thanh Phát  CKM    10
# 6   7  21456985          Lý Mạc Sầu  CKM    10
# 7   8  19566589      Nguyễn Anh Thư  CKM    10
# 8   9  20146179        Lê Thanh Tâm  CKM    10
# 9  10  20146182        Lý Minh Nhựt  CKM    10

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.groupby('Khoa').count()
# Out:
#       No  MSSV  Họ và tên  Điểm
# Khoa
# CKM   20    20         20    20

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.groupby(['Khoa','Điểm']).count()
# Out:
#            No  MSSV  Họ và tên
# Khoa Điểm
# CKM  10    20    20         20

# %%
import pandas as pd
url='AITUAN.csv'
dataframe.groupby('Khoa')['Điểm'].count()
# Out:
# Khoa
# CKM    20
# Name: Điểm, dtype: int64

# %%
from IPython.lib.security import random
import pandas as pd
import numpy as np
time_index=pd.data_range('01/01/2023', penods=100000, freg ='30s')
dataframe=pd.dataframe(index=time_index)
dataframe['Acess Amount']=np.random.randint(1,10,100000)
dataframe.resample('W').son()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-6516c057e397> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 time_index=pd.data_range('01/01/2023', penods=100000, freg ='30s')
#       5 dataframe=pd.dataframe(index=time_index)
#       6 dataframe['Acess Amount']=np.random.randint(1,10,100000)
#
# /usr/local/lib/python3.8/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'data_range'

# %%
from pandas._libs.tslibs import period
from os import times_result
import pandas as pd
import numpy as np
time_index=pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Amount']=np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14664
# 2023-01-08        100129
# 2023-01-15        100581
# 2023-01-22        100692
# 2023-01-29        100402
# 2023-02-05         82000

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
dataframe.groupby('City')['Medal'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-0d9bc6e7f6db> in <module>
#       2 url='http://winterolympicsmedals.com/medals.csv'
#       3 data=pd.read_csv(url)
# ----> 4 dataframe.groupby('City')['Medal'].count()
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
dataframe=pd.read_csv(url)
dataframe.groupby('City')['Medal'].count()
# Out:
# City
# Albertville               171
# Calgary                   138
# Chamonix                   49
# Cortina d'Ampezzo          72
# Garmisch-Partenkirchen     51
# Grenoble                  106
# Innsbruck                 214
# Lake Placid               157
# Lillehammer               183
# Nagano                    205
# Oslo                       67
# Salt Lake City            234
# Sapporo                   105
# Sarajevo                  117
# Squaw Valley               81
# St. Moritz                109
# Turin                     252
# Name: Medal, dtype: int64

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data[data['NOC']=='CAN'].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].head(2300)
# Out:
#       Year            City      Sport  ...       Event Event gender Medal
# 1     1924        Chamonix    Skating  ...  individual            W  Gold
# 36    1924        Chamonix     Skiing  ...  individual            M  Gold
# 44    1924        Chamonix    Skating  ...  individual            M  Gold
# 62    1928      St. Moritz    Skating  ...  individual            W  Gold
# 73    1928      St. Moritz     Skiing  ...  individual            M  Gold
# ...    ...             ...        ...  ...         ...          ...   ...
# 2037  2002  Salt Lake City    Skating  ...  individual            W  Gold
# 2087  2006           Turin  Bobsleigh  ...  individual            M  Gold
# 2190  2006           Turin    Skating  ...  individual            W  Gold
# 2241  2006           Turin    Skating  ...  individual            M  Gold
# 2258  2006           Turin  Bobsleigh  ...  individual            W  Gold
#
# [65 rows x 8 columns]

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data[data['NOC']=='CAN'].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].value_counts()
# Out:
# Year  City       Sport    Discipline       NOC  Event       Event gender  Medal
# 1924  Chamonix   Skating  Figure skating   AUT  individual  W             Gold     1
# 1972  Sapporo    Skating  Figure skating   TCH  individual  M             Gold     1
# 1976  Innsbruck  Skating  Figure skating   GBR  individual  M             Gold     1
#                                            USA  individual  W             Gold     1
#                  Skiing   Nordic Combined  GDR  individual  M             Gold     1
#                                                                                   ..
# 1964  Innsbruck  Skating  Figure skating   NED  individual  W             Gold     1
#                  Skiing   Nordic Combined  NOR  individual  M             Gold     1
# 1968  Grenoble   Skating  Figure skating   AUT  individual  M             Gold     1
#                                            USA  individual  W             Gold     1
# ...

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
dataframe.groupby('NOC')['Medal'].count()
# Out:
# NOC
# AUS      6
# AUT    185
# BEL      5
# BLR      6
# BUL      6
# CAN    119
# CHN     33
# CRO      7
# CZE     10
# DEN      1
# ESP      2
# EST      6
# EUA     19
# EUN     23
# FIN    151
# FRA     83
# FRG     41
# GBR     21
# GDR    110
# GER    158
# HUN      6
# ITA    101
# JPN     32
# KAZ      5
# KOR     31
# LAT      1
# LIE      9
# LUX      2
# NED     78
# NOR    280
# NZL      1
# POL      8
# PRK      2
# ROU      1
# RUS     76
# SLO      4
# SUI    118
# SVK      1
# SWE    118
# TCH     25
# UKR      5
# URS    194
# USA    216
# UZB      1
# YUG      4
# Name: Medal, dtype: int64

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data[data['NOC']=='USA'].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].value_counts()
# Out:
# Year  City       Sport    Discipline       NOC  Event       Event gender  Medal
# 1924  Chamonix   Skating  Figure skating   AUT  individual  W             Gold     1
# 1972  Sapporo    Skating  Figure skating   TCH  individual  M             Gold     1
# 1976  Innsbruck  Skating  Figure skating   GBR  individual  M             Gold     1
#                                            USA  individual  W             Gold     1
#                  Skiing   Nordic Combined  GDR  individual  M             Gold     1
#                                                                                   ..
# 1964  Innsbruck  Skating  Figure skating   NED  individual  W             Gold     1
#                  Skiing   Nordic Combined  NOR  individual  M             Gold     1
# 1968  Grenoble   Skating  Figure skating   AUT  individual  M             Gold     1
#                                            USA  individual  W             Gold     1
# ...
